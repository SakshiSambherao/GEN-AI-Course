# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.13/dist-packages (2.54.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from openai) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from openai) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.13/dist-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.13/dist-packages (from openai) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5,>=3.5.0->openai) (3.19)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->openai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->openai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.4)

# %%
from google.colab import userdata
from openai import OpenAI

# 1. Fetch your OpenRouter key safely from Colab Secrets
OPENROUTER_API_KEY = userdata.get('GenAi_Chatbot')

# 2. Initialize the OpenAI client properly
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY,
)

# 3. Setup your prompt
prompt_text = "Give me tips to not to sleep during lecture"

# 4. Use a completely new variable name to bypass Colab's cached memory string
completion_result = client.chat.completions.create(
    model="openrouter/free",
    messages=[
        {"role": "user", "content": prompt_text}
    ]
)

# 5. Extract and print the final generated message
print(completion_result.choices[0].message.content)
# Out:
# Of course! Staying awake during a lecture is a common challenge. The key is to be proactive and strategic, not just reactive. Here are tips categorized into before, during, and after the lecture, plus some lifestyle factors.
#
# ### **Before the Lecture: Preparation is Key**
#
# 1.  **Get a Good Night's Sleep:** This is the most important rule. No amount of caffeine can compensate for 4 hours of sleep. Prioritize sleep over cramming.
# 2.  **Eat a Light, Balanced Meal:** Avoid heavy, carb-loaded meals (like a huge bowl of pasta) right before class, as they can make you sluggish. Opt for protein and complex carbs (e.g., a turkey sandwich, yogurt with fruit, or an apple with peanut butter).
# 3.  **Hydrate, But Not Excessively:** Drink water before class. Dehydration causes fatigue. Just be mindful of needing too many bathroom breaks during the lecture.
# 4.  **Get Some Morning Exercise:** Even a 10-minute walk or some light stretching can boost your energy and alertness for the day.
# 5.  **Have a Stimulant Ready (in Moderation):** A cup of coffee or tea about 30-60 minutes before class can be very effective. The caffeine peak will align with the lecture. Avoid sugary energy drinks that lead to a crash.
#
# ### **During the Lecture: Be an Active Participant**
#
# This is where you can fight the urge to sleep in real-time.
#
# **Physical Strategies:**
# 1.  **Sit Up Straight:** Slouching reduces oxygen flow and signals your body to relax. Sit tall, with your feet flat on the floor.
# 2.  **Engage Your Core:** Gently tighten your abdominal muscles. This subtle action increases alertness and blood flow.
# 3.  **Move Your Feet and Ankles:** Simply flexing your foot up and down or circling your ankles keeps blood circulating without being distracting.
# 4.  **Take Deep Breaths:** If you feel drowsy, take a slow, deep breath in through your nose and exhale through your mouth. This increases oxygen in your bloodstream.
# 5.  **The Pinch (Use as a Last Resort):** If you're on the verge of falling asleep, use a pen or your fingernail to gently press into your finger or arm. The mild discomfort can jolt you awake.
#
# **Mental Strategies:**
# 1.  **Be an Active Listener:** Don't just passively absorb information. constantly ask yourself questions: "What is the main point?" "How does this connect to what I already know?" "What is the evidence for this claim?"
# 2.  **Take Notes by Hand:** The physical act of writing forces your brain to process and summarize information, which is much more engaging than typing verbatim. It keeps your hands and mind busy.
# 3.  **Predict the Next Point:** Try to anticipate what the professor will say next. This turns you into a detective of the material, keeping your mind sharp.
# 4.  **Focus on the Professor's Body Language and Passion:** Pay attention to their gestures, tone of voice, and enthusiasm for the subject. This can be contagious and help you stay engaged.
#
# ### **Lifestyle & Environmental Factors**
#
# 1.  **Choose Your Seat Wisely:**
#     *   **Front Row:** Close proximity to the board and the professor makes it harder to zone out. You're also less likely to be distracted by others.
#     *   **Avoid the Back Corners:** These are the classic "sleep zones."
#     *   **Near the Front/Center:** A good middle-ground option.
# 2.  **Keep the Room Cool:** A warm room promotes sleep. If you can, sit near a vent or open a window if possible.
# 3.  **Manage Screen Time:** Avoid scrolling on your phone or laptop for non-lecture purposes. The blue light and mental distraction will make it harder to focus.
#
# ### **Quick "Emergency" Wake-Up Techniques**
#
# If you feel sleep overwhelming you *during* the lecture:
#
# *   **Bite Your Tongue Gently:** The slight pain can be a surprising wake-up call.
# *   **Hold Your Breath:** For 10-15 seconds. This increases CO2 levels and can make you feel more alert.
# *   **Drink a Sip of Cold Water:** The shock of cold can be effective.
# *   **Excuse Yourself for a Quick Break:** If it's really bad, it's better to step outside for 60 seconds to splash water on your face or get some fresh air than to sleep through the entire lecture.
#
# **Remember:** The goal is to **learn**, not just to survive the hour. Combining these strategies will not only keep you awake but also help you retain the information much better. Good luck
